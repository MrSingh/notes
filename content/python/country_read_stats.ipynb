# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data
data = {
    'Country': [
        'India', 'Thailand', 'China', 'Philippines', 'Egypt', 'Czech Republic', 
        'Sweden', 'France', 'Hungary', 'Saudi Arabia', 'Hong Kong', 'Poland', 
        'Venezuela', 'South Africa', 'Australia', 'Indonesia', 'Argentina', 
        'Turkey', 'Spain', 'Canada', 'Germany', 'USA', 'Italy', 'Mexico', 
        'UK', 'Brazil', 'Taiwan', 'Japan', 'South Korea'
    ],
    'Hours per Week': [
        10.42, 9.24, 8.00, 7.36, 7.30, 7.24, 7.06, 6.54, 6.48, 6.48, 
        6.42, 6.30, 6.24, 6.18, 6.18, 6.00, 5.54, 5.54, 5.48, 5.48, 
        5.42, 5.42, 5.36, 5.30, 5.18, 5.12, 5.00, 4.06, 3.06
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort DataFrame
df = df.sort_values(by='Hours per Week', ascending=False)

# Plot
plt.figure(figsize=(15, 10))
plt.barh(df['Country'], df['Hours per Week'], color='skyblue')
plt.xlabel('Hours Spent Reading per Week')
plt.title('Average Hours Spent Reading per Person per Week by Country')
plt.grid(axis='x')

# Add flags
flags = {
    'India': '🇮🇳', 'Thailand': '🇹🇭', 'China': '🇨🇳', 'Philippines': '🇵🇭', 'Egypt': '🇪🇬',
    'Czech Republic': '🇨🇿', 'Sweden': '🇸🇪', 'France': '🇫🇷', 'Hungary': '🇭🇺', 
    'Saudi Arabia': '🇸🇦', 'Hong Kong': '🇭🇰', 'Poland': '🇵🇱', 'Venezuela': '🇻🇪', 
    'South Africa': '🇿🇦', 'Australia': '🇦🇺', 'Indonesia': '🇮🇩', 'Argentina': '🇦🇷', 
    'Turkey': '🇹🇷', 'Spain': '🇪🇸', 'Canada': '🇨🇦', 'Germany': '🇩🇪', 'USA': '🇺🇸', 
    'Italy': '🇮🇹', 'Mexico': '🇲🇽', 'UK': '🇬🇧', 'Brazil': '🇧🇷', 'Taiwan': '🇹🇼', 
    'Japan': '🇯🇵', 'South Korea': '🇰🇷'
}

for i, country in enumerate(df['Country']):
    plt.text(df['Hours per Week'].iloc[i], i, flags[country], fontsize=15, verticalalignment='center')

plt.show()
# Out:
# C:\Users\pthuk\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127470 (\N{REGIONAL INDICATOR SYMBOL LETTER I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\pthuk\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127475 (\N{REGIONAL INDICATOR SYMBOL LETTER N}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\pthuk\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127481 (\N{REGIONAL INDICATOR SYMBOL LETTER T}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\pthuk\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127469 (\N{REGIONAL INDICATOR SYMBOL LETTER H}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import numpy as np

# Data
data = {
    'Country': [
        'India', 'Thailand', 'China', 'Philippines', 'Egypt', 'Czech Republic', 
        'Sweden', 'France', 'Hungary', 'Saudi Arabia', 'Hong Kong', 'Poland', 
        'Venezuela', 'South Africa', 'Australia', 'Indonesia', 'Argentina', 
        'Turkey', 'Spain', 'Canada', 'Germany', 'USA', 'Italy', 'Mexico', 
        'UK', 'Brazil', 'Taiwan', 'Japan', 'South Korea'
    ],
    'Hours per Week': [
        10.42, 9.24, 8.00, 7.36, 7.30, 7.24, 7.06, 6.54, 6.48, 6.48, 
        6.42, 6.30, 6.24, 6.18, 6.18, 6.00, 5.54, 5.54, 5.48, 5.48, 
        5.42, 5.42, 5.36, 5.30, 5.18, 5.12, 5.00, 4.06, 3.06
    ],
    'Flag': [
        'india.png', 'thailand.png', 'china.png', 'philippines.png', 'egypt.png',
        'czech_republic.png', 'sweden.png', 'france.png', 'hungary.png', 
        'saudi_arabia.png', 'hong_kong.png', 'poland.png', 'venezuela.png', 
        'south_africa.png', 'australia.png', 'indonesia.png', 'argentina.png', 
        'turkey.png', 'spain.png', 'canada.png', 'germany.png', 'usa.png', 
        'italy.png', 'mexico.png', 'uk.png', 'brazil.png', 'taiwan.png', 
        'japan.png', 'south_korea.png'
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort DataFrame
df = df.sort_values(by='Hours per Week', ascending=False)

# Plot
fig, ax = plt.subplots(figsize=(15, 10))
bars = ax.barh(df['Country'], df['Hours per Week'], color='skyblue')
ax.set_xlabel('Hours Spent Reading per Week')
ax.set_title('Average Hours Spent Reading per Person per Week by Country')
ax.grid(axis='x')

# Add flag images
for i, country in enumerate(df['Country']):
    flag = Image.open(f'flags/{df["Flag"].iloc[i]}')
    flag = flag.resize((30, 20), Image.ANTIALIAS)
    ax.imshow(flag, aspect='auto', extent=[df['Hours per Week'].iloc[i] - 0.4, df['Hours per Week'].iloc[i], i - 0.35, i + 0.35], zorder=-1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 46
#      44 # Add flag images
#      45 for i, country in enumerate(df['Country']):
# ---> 46     flag = Image.open(f'flags/{df["Flag"].iloc[i]}')
#      47     flag = flag.resize((30, 20), Image.ANTIALIAS)
#      48     ax.imshow(flag, aspect='auto', extent=[df['Hours per Week'].iloc[i] - 0.4, df['Hours per Week'].iloc[i], i - 0.35, i + 0.35], zorder=-1)
#
# File c:\Python312\Lib\site-packages\PIL\Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\pthuk\\Documents\\git\\notes\\content\\python\\flags\\india.png'

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data
data = {
    'Country': [
        'India', 'Thailand', 'China', 'Philippines', 'Egypt', 'Czech Republic', 
        'Sweden', 'France', 'Hungary', 'Saudi Arabia', 'Hong Kong', 'Poland', 
        'Venezuela', 'South Africa', 'Australia', 'Indonesia', 'Argentina', 
        'Turkey', 'Spain', 'Canada', 'Germany', 'USA', 'Italy', 'Mexico', 
        'UK', 'Brazil', 'Taiwan', 'Japan', 'South Korea'
    ],
    'Hours per Week': [
        10.42, 9.24, 8.00, 7.36, 7.30, 7.24, 7.06, 6.54, 6.48, 6.48, 
        6.42, 6.30, 6.24, 6.18, 6.18, 6.00, 5.54, 5.54, 5.48, 5.48, 
        5.42, 5.42, 5.36, 5.30, 5.18, 5.12, 5.00, 4.06, 3.06
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort DataFrame
df = df.sort_values(by='Hours per Week', ascending=False)

# Plot
plt.figure(figsize=(15, 10))
bars = plt.barh(df['Country'], df['Hours per Week'], color='skyblue')

# Add labels and annotations
for i, bar in enumerate(bars):
    plt.text(
        bar.get_width() + 0.1, 
        bar.get_y() + bar.get_height() / 2, 
        f'{df["Hours per Week"].iloc[i]}', 
        va='center',
        fontsize=10
    )

plt.xlabel('Hours Spent Reading per Week')
plt.title('Average Hours Spent Reading per Person per Week by Country')

# Highlight highest and lowest values
plt.barh(df['Country'][0], df['Hours per Week'][0], color='gold')
plt.barh(df['Country'].iloc[-1], df['Hours per Week'].iloc[-1], color='red')

plt.grid(axis='x')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data
data = {
    'Country': [
        'India', 'Thailand', 'China', 'Philippines', 'Egypt', 'Czech Republic', 
        'Sweden', 'France', 'Hungary', 'Saudi Arabia', 'Hong Kong', 'Poland', 
        'Venezuela', 'South Africa', 'Australia', 'Indonesia', 'Argentina', 
        'Turkey', 'Spain', 'Canada', 'Germany', 'USA', 'Italy', 'Mexico', 
        'UK', 'Brazil', 'Taiwan', 'Japan', 'South Korea'
    ],
    'Hours per Week': [
        10.42, 9.24, 8.00, 7.36, 7.30, 7.24, 7.06, 6.54, 6.48, 6.48, 
        6.42, 6.30, 6.24, 6.18, 6.18, 6.00, 5.54, 5.54, 5.48, 5.48, 
        5.42, 5.42, 5.36, 5.30, 5.18, 5.12, 5.00, 4.06, 3.06
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort DataFrame by Hours per Week in descending order
df = df.sort_values(by='Hours per Week', ascending=True)

# Plot
plt.figure(figsize=(15, 10))
bars = plt.barh(df['Country'], df['Hours per Week'], color='lightgrey')

# Add labels and annotations
for i, bar in enumerate(bars):
    plt.text(
        bar.get_width() + 0.1, 
        bar.get_y() + bar.get_height() / 2, 
        f'{df["Hours per Week"].iloc[i]}', 
        va='center',
        fontsize=10
    )

plt.xlabel('Hours Spent Reading per Week')
plt.title('Average Hours Spent Reading per Person per Week by Country')

# Highlight highest and lowest values
plt.barh(df['Country'].iloc[-1], df['Hours per Week'].iloc[-1], color='green')
plt.barh(df['Country'].iloc[0], df['Hours per Week'].iloc[0], color='red')

plt.grid(axis='x')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data
data = {
    'Country': [
        'India', 'Thailand', 'China', 'Philippines', 'Egypt', 'Czech Republic', 
        'Sweden', 'France', 'Hungary', 'Saudi Arabia', 'Hong Kong', 'Poland', 
        'Venezuela', 'South Africa', 'Australia', 'Indonesia', 'Argentina', 
        'Turkey', 'Spain', 'Canada', 'Germany', 'USA', 'Italy', 'Mexico', 
        'UK', 'Brazil', 'Taiwan', 'Japan', 'South Korea'
    ],
    'Hours per Week': [
        10.42, 9.24, 8.00, 7.36, 7.30, 7.24, 7.06, 6.54, 6.48, 6.48, 
        6.42, 6.30, 6.24, 6.18, 6.18, 6.00, 5.54, 5.54, 5.48, 5.48, 
        5.42, 5.42, 5.36, 5.30, 5.18, 5.12, 5.00, 4.06, 3.06
    ],
    'Flag': [
        '🇮🇳', '🇹🇭', '🇨🇳', '🇵🇭', '🇪🇬', '🇨🇿', '🇸🇪', '🇫🇷', '🇭🇺', 
        '🇸🇦', '🇭🇰', '🇵🇱', '🇻🇪', '🇿🇦', '🇦🇺', '🇮🇩', '🇦🇷', '🇹🇷', 
        '🇪🇸', '🇨🇦', '🇩🇪', '🇺🇸', '🇮🇹', '🇲🇽', '🇬🇧', '🇧🇷', '🇹🇼', 
        '🇯🇵', '🇰🇷'
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort DataFrame by Hours per Week in descending order
df = df.sort_values(by='Hours per Week', ascending=True)

# Plot
plt.figure(figsize=(15, 10))
bars = plt.barh(df['Country'], df['Hours per Week'], color='skyblue')

# Add labels and annotations
for i, bar in enumerate(bars):
    plt.text(
        bar.get_width() + 0.1, 
        bar.get_y() + bar.get_height() / 2, 
        f'{df["Flag"].iloc[i]} {df["Hours per Week"].iloc[i]}', 
        va='center',
        fontsize=10
    )

plt.xlabel('Hours Spent Reading per Week')
plt.title('Average Hours Spent Reading per Person per Week by Country')

# Highlight highest and lowest values
plt.barh(df['Country'].iloc[-1], df['Hours per Week'].iloc[-1], color='gold')
plt.barh(df['Country'].iloc[0], df['Hours per Week'].iloc[0], color='red')

plt.grid(axis='x')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import requests
from io import BytesIO

# Data
data = {
    'Country': [
        'India', 'Thailand', 'China', 'Philippines', 'Egypt', 'Czech Republic', 
        'Sweden', 'France', 'Hungary', 'Saudi Arabia', 'Hong Kong', 'Poland', 
        'Venezuela', 'South Africa', 'Australia', 'Indonesia', 'Argentina', 
        'Turkey', 'Spain', 'Canada', 'Germany', 'USA', 'Italy', 'Mexico', 
        'UK', 'Brazil', 'Taiwan', 'Japan', 'South Korea'
    ],
    'Hours per Week': [
        10.42, 9.24, 8.00, 7.36, 7.30, 7.24, 7.06, 6.54, 6.48, 6.48, 
        6.42, 6.30, 6.24, 6.18, 6.18, 6.00, 5.54, 5.54, 5.48, 5.48, 
        5.42, 5.42, 5.36, 5.30, 5.18, 5.12, 5.00, 4.06, 3.06
    ],
    'Flag_URL': [
        'https://flagcdn.com/w320/in.png', 'https://flagcdn.com/w320/th.png', 'https://flagcdn.com/w320/cn.png', 
        'https://flagcdn.com/w320/ph.png', 'https://flagcdn.com/w320/eg.png', 'https://flagcdn.com/w320/cz.png', 
        'https://flagcdn.com/w320/se.png', 'https://flagcdn.com/w320/fr.png', 'https://flagcdn.com/w320/hu.png', 
        'https://flagcdn.com/w320/sa.png', 'https://flagcdn.com/w320/hk.png', 'https://flagcdn.com/w320/pl.png', 
        'https://flagcdn.com/w320/ve.png', 'https://flagcdn.com/w320/za.png', 'https://flagcdn.com/w320/au.png', 
        'https://flagcdn.com/w320/id.png', 'https://flagcdn.com/w320/ar.png', 'https://flagcdn.com/w320/tr.png', 
        'https://flagcdn.com/w320/es.png', 'https://flagcdn.com/w320/ca.png', 'https://flagcdn.com/w320/de.png', 
        'https://flagcdn.com/w320/us.png', 'https://flagcdn.com/w320/it.png', 'https://flagcdn.com/w320/mx.png', 
        'https://flagcdn.com/w320/gb.png', 'https://flagcdn.com/w320/br.png', 'https://flagcdn.com/w320/tw.png', 
        'https://flagcdn.com/w320/jp.png', 'https://flagcdn.com/w320/kr.png'
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort DataFrame by Hours per Week in descending order
df = df.sort_values(by='Hours per Week', ascending=False)

# Plot
fig, ax = plt.subplots(figsize=(15, 10))
bars = ax.barh(df['Country'], df['Hours per Week'], color='skyblue')
ax.set_xlabel('Hours Spent Reading per Week')
ax.set_title('Average Hours Spent Reading per Person per Week by Country')

# Add flag images
for i, country in enumerate(df['Country']):
    response = requests.get(df['Flag_URL'].iloc[i])
    img = Image.open(BytesIO(response.content))
    img = img.resize((30, 20), Image.LANCZOS)
    ax.imshow(img, aspect='auto', extent=[df['Hours per Week'].iloc[i] - 0.4, df['Hours per Week'].iloc[i], i - 0.35, i + 0.35], zorder=-1)

# Highlight highest and lowest values
plt.barh(df['Country'].iloc[0], df['Hours per Week'].iloc[0], color='gold')
plt.barh(df['Country'].iloc[-1], df['Hours per Week'].iloc[-1], color='red')

plt.grid(axis='x')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import requests
from io import BytesIO

# Data
data = {
    'Country': [
        'India', 'Thailand', 'China', 'Philippines', 'Egypt', 'Czech Republic', 
        'Sweden', 'France', 'Hungary', 'Saudi Arabia', 'Hong Kong', 'Poland', 
        'Venezuela', 'South Africa', 'Australia', 'Indonesia', 'Argentina', 
        'Turkey', 'Spain', 'Canada', 'Germany', 'USA', 'Italy', 'Mexico', 
        'UK', 'Brazil', 'Taiwan', 'Japan', 'South Korea'
    ],
    'Hours per Week': [
        10.42, 9.24, 8.00, 7.36, 7.30, 7.24, 7.06, 6.54, 6.48, 6.48, 
        6.42, 6.30, 6.24, 6.18, 6.18, 6.00, 5.54, 5.54, 5.48, 5.48, 
        5.42, 5.42, 5.36, 5.30, 5.18, 5.12, 5.00, 4.06, 3.06
    ],
    'Flag_URL': [
        'https://flagcdn.com/w320/in.png', 'https://flagcdn.com/w320/th.png', 'https://flagcdn.com/w320/cn.png', 
        'https://flagcdn.com/w320/ph.png', 'https://flagcdn.com/w320/eg.png', 'https://flagcdn.com/w320/cz.png', 
        'https://flagcdn.com/w320/se.png', 'https://flagcdn.com/w320/fr.png', 'https://flagcdn.com/w320/hu.png', 
        'https://flagcdn.com/w320/sa.png', 'https://flagcdn.com/w320/hk.png', 'https://flagcdn.com/w320/pl.png', 
        'https://flagcdn.com/w320/ve.png', 'https://flagcdn.com/w320/za.png', 'https://flagcdn.com/w320/au.png', 
        'https://flagcdn.com/w320/id.png', 'https://flagcdn.com/w320/ar.png', 'https://flagcdn.com/w320/tr.png', 
        'https://flagcdn.com/w320/es.png', 'https://flagcdn.com/w320/ca.png', 'https://flagcdn.com/w320/de.png', 
        'https://flagcdn.com/w320/us.png', 'https://flagcdn.com/w320/it.png', 'https://flagcdn.com/w320/mx.png', 
        'https://flagcdn.com/w320/gb.png', 'https://flagcdn.com/w320/br.png', 'https://flagcdn.com/w320/tw.png', 
        'https://flagcdn.com/w320/jp.png', 'https://flagcdn.com/w320/kr.png'
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort DataFrame by Hours per Week in descending order
df = df.sort_values(by='Hours per Week', ascending=True)

# Plot
fig, ax = plt.subplots(figsize=(15, 10))
bars = ax.barh(df['Country'], df['Hours per Week'], color='skyblue')
ax.set_xlabel('Hours Spent Reading per Week')
ax.set_title('Average Hours Spent Reading per Person per Week by Country')

# Add flag images and numbers
for i, country in enumerate(df['Country']):
    response = requests.get(df['Flag_URL'].iloc[i])
    img = Image.open(BytesIO(response.content))
    img = img.resize((30, 20), Image.LANCZOS)
    ax.imshow(img, aspect='auto', extent=[-0.5, -0.2, i - 0.35, i + 0.35], zorder=1)
    plt.text(
        df['Hours per Week'].iloc[i] + 0.1, 
        i, 
        f'{df["Hours per Week"].iloc[i]}', 
        va='center',
        fontsize=10
    )

# Highlight highest and lowest values
plt.barh(df['Country'].iloc[0], df['Hours per Week'].iloc[0], color='gold')
plt.barh(df['Country'].iloc[-1], df['Hours per Week'].iloc[-1], color='red')

plt.grid(axis='x')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import requests
from io import BytesIO

# Data
data = {
    'Country': [
        'India', 'Thailand', 'China', 'Philippines', 'Egypt', 'Czech Republic', 
        'Sweden', 'France', 'Hungary', 'Saudi Arabia', 'Hong Kong', 'Poland', 
        'Venezuela', 'South Africa', 'Australia', 'Indonesia', 'Argentina', 
        'Turkey', 'Spain', 'Canada', 'Germany', 'USA', 'Italy', 'Mexico', 
        'UK', 'Brazil', 'Taiwan', 'Japan', 'South Korea'
    ],
    'Hours per Week': [
        10.42, 9.24, 8.00, 7.36, 7.30, 7.24, 7.06, 6.54, 6.48, 6.48, 
        6.42, 6.30, 6.24, 6.18, 6.18, 6.00, 5.54, 5.54, 5.48, 5.48, 
        5.42, 5.42, 5.36, 5.30, 5.18, 5.12, 5.00, 4.06, 3.06
    ],
    'Flag_URL': [
        'https://flagcdn.com/w320/in.png', 'https://flagcdn.com/w320/th.png', 'https://flagcdn.com/w320/cn.png', 
        'https://flagcdn.com/w320/ph.png', 'https://flagcdn.com/w320/eg.png', 'https://flagcdn.com/w320/cz.png', 
        'https://flagcdn.com/w320/se.png', 'https://flagcdn.com/w320/fr.png', 'https://flagcdn.com/w320/hu.png', 
        'https://flagcdn.com/w320/sa.png', 'https://flagcdn.com/w320/hk.png', 'https://flagcdn.com/w320/pl.png', 
        'https://flagcdn.com/w320/ve.png', 'https://flagcdn.com/w320/za.png', 'https://flagcdn.com/w320/au.png', 
        'https://flagcdn.com/w320/id.png', 'https://flagcdn.com/w320/ar.png', 'https://flagcdn.com/w320/tr.png', 
        'https://flagcdn.com/w320/es.png', 'https://flagcdn.com/w320/ca.png', 'https://flagcdn.com/w320/de.png', 
        'https://flagcdn.com/w320/us.png', 'https://flagcdn.com/w320/it.png', 'https://flagcdn.com/w320/mx.png', 
        'https://flagcdn.com/w320/gb.png', 'https://flagcdn.com/w320/br.png', 'https://flagcdn.com/w320/tw.png', 
        'https://flagcdn.com/w320/jp.png', 'https://flagcdn.com/w320/kr.png'
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort DataFrame by Hours per Week in descending order
df = df.sort_values(by='Hours per Week', ascending=False)

# Plot
fig, ax = plt.subplots(figsize=(15, 10))
bars = ax.barh(df['Country'], df['Hours per Week'], color='skyblue')
ax.set_xlabel('Hours Spent Reading per Week')
ax.set_title('Average Hours Spent Reading per Person per Week by Country')

# Add flag images and numbers
for i, country in enumerate(df['Country']):
    response = requests.get(df['Flag_URL'].iloc[i])
    img
