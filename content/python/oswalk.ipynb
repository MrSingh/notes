# %% [markdown]
# ---
# title: "Python os.walk()"
# Description: "Python method walk() generates directory file names."
# date: 2021-01-28T14:50:18Z
# draft: false
# ---
#
# ***

# %% [markdown]
# ## Import Modules

# %%
# Import Module
import os

# %% [markdown]
# ## Set Path

# %%
# Set Path
path = '../../content/'

# %% [markdown]
# ## Find All Markdown Files In All Content Folders

# %%
# Find all markdown filesin all content folders
all_md_files = [os.path.join(root, name)
    for root, dirs, files in os.walk(path)
        for name in files
            if name.endswith((".md"))]
all_md_files
# Out:
# ['../../content/_index.md',
#  '../../content/javascript/master_javascript_mindmap.md',
#  '../../content/vscode/vscode_shortcuts.md',
#  '../../content/vscode/inserting_date_time.md',
#  '../../content/vscode/vscode_python_issues.md',
#  '../../content/_python_drafts/multi/README.md',
#  '../../content/read/reading_log.md',
#  '../../content/read/bookshelf_home.md',
#  '../../content/read/_master_book_list.md',
#  '../../content/read/bookshelf.md',
#  '../../content/python/load_json.md',
#  '../../content/python/load_csv.md',
#  '../../content/python/oswalk.md',
#  '../../content/python/creating_arrays.md',
#  '../../content/python/format_basics.md',
#  '../../content/python/ws_requests_and_beautifulsoup.md',
#  '../../content/python/brooks_data_analysis.md',
#  '../../content/python/co2_emissions_eda.md',
#  '../../content/python/write_dataframe_to_json.md',
#  '../../content/python/while_loop_basics.md',
#  '../../content/python/stock_market_analysis.md',
#  '../../content/python/for_loop_basics.md',
#  '../../content/python/moving_average_analysis.md',
#  '../../content/python/image_to_passport.md',
#  '../../content/python/Untitled.md',
#  '../../content/python/resources.md',
#  '../../content/python/investment_analysis.md',
#  '../../content/python/normalise_multiindex_data.md',
#  '../../content/python/ossystem.md',
#  '../../content/python/co2_emmisions_analysis.md',
#  '../../content/python/drop_dataframe_columns.md',
#  '../../content/python/flatten_multiindex_dataframe.md',
#  '../../content/python/primitive_data_types.md',
#  '../../content/notes/llm_limitations.md',
#  '../../content/notes/understanding_the_llm_context_window.md',
#  '../../content/notes/euro_2024.md',
#  '../../content/notes/log.md',
#  '../../content/notes/Site Changes - Combining Obsidian, Hugo and Github for an improved workflow.md',
#  '../../content/notes/project_esg_report.md',
#  '../../content/notes/intro_ppdac.md',
#  '../../content/notes/pdf_to_kindle.md',
#  '../../content/notes/alternative_data_alpha.md',
#  '../../content/notes/copilot_menu.md',
#  '../../content/notes/first_30_days.md',
#  '../../content/notes/snowflake_2025_trends.md',
#  '../../content/notes/normalising_data.md',
#  '../../content/notes/data_quality.md',
#  '../../content/notes/data_resources.md',
#  '../../content/notes/financial_crime.md',
#  '../../content/notes/_index.md',
#  '../../content/notes/openclaw_first_impressions.md',
#  '../../content/summer_school/week_one.md',
#  '../../content/summer_school/week_six.md',
#  '../../content/summer_school/summer_school.md',
#  '../../content/summer_school/week_two.md',
#  '../../content/summer_school/week_three.md',
#  '../../content/summer_school/week_nine.md',
#  '../../content/summer_school/week_five.md',
#  '../../content/summer_school/week_seven.md',
#  '../../content/summer_school/week_four.md',
#  '../../content/summer_school/week_eight.md',
#  '../../content/summer_school/week_ten.md',
#  '../../content/about_me/about_me.md',
#  '../../content/resources/_index.md',
#  '../../content/home/home.md',
#  '../../content/code/code.md',
#  '../../content/git/basic_git_commands.md',
#  '../../content/git/add_existing_project_to_github.md']
